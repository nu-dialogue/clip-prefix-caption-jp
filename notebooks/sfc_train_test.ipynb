# %% [markdown]
# # 準備

# %% [markdown]
# ## 1-1. 作業用ディレクトリ準備

# %%
#@markdown ## 1. 作業用ディレクトリを準備する

# マウント
from google.colab import drive 
drive.mount('/content/drive')

# 作業用ディレクトリを作成して移動
EXP_DPATH = '/content/drive/MyDrive/SFC_2021_clip_prefix_caption'
# !mkdir -p $EXP_DPATH
# %cd $EXP_DPATH

# %% [markdown]
# ## 1-2. ライブラリのインストール&インポート

# %%
# インストール

import os
import sys

# レポジトリをクローンして移動
REPO_DPATH = os.path.join(EXP_DPATH, 'clip-prefix-caption-jp')
if not os.path.exists(REPO_DPATH):
    # !git clone https://github.com/ohashi56225/clip-prefix-caption-jp.git
# %cd $REPO_DPATH

# 必要ライブラリインストール
# !pip install git+https://github.com/openai/CLIP.git
# !pip install scikit-image torch transformers sentencepiece
sys.path.append(REPO_DPATH)

# %%
# インポート

import json
import random
from preprocess import prepare_data
from test import Predictor
from model import build_model
# from IPython.display import display
# from google.colab import files

# # ついでに後で使う関数も作っておく
# def upload_file():
#   uploaded = files.upload()
#   if not uploaded:
#     image_fpath = ''
#   elif len(uploaded) == 1:
#     image_fpath = list(uploaded.keys())[0]
#   else:
#     raise RuntimeError("1度に1枚まで")
#   return image_fpath

# %% [markdown]
# # 2. cocoデータセットのみで学習

# %% [markdown]
# ## 2-1. cocoデータの準備
# キャプション一覧データと画像データを用意する．各データのフォーマットは，本リポジトリの`README.md`を参照．

# %%
# キャプション一覧データのパス
captions_fpath = "data/coco/captions.json"

# 画像データのパス
image_dpath = "data/coco/images"

# %% [markdown]
# ## 2-2. 学習データの生成
# CLIPモデルを用いて，用意したcocoデータから学習データを作成する．

# %%
# train/test/validの割合を指定
coco_test_fpath, coco_valid_fpath, coco_train_fpath = prepare_data(captions_fpath=captions_fpath,
                                                                   image_dpath=image_dpath,
                                                                   test_ratio=0.1,
                                                                   valid_ratio=0.1,
                                                                   train_ratio=0.8,
                                                                   shuffle=False)

# %% [markdown]
# ## 2-3. 学習

# %%
# !python train.py --model_name coco \
                 --train_data_fpath $coco_train_fpath \
                 --valid_data_fpath $coco_valid_fpath \
                 --epochs 10 \
                 --batch_size 40
# Out:
# Data size is 105392
# Data size is 13174
# Train both prefix and GPT
# Resume pretrained weights from checkpoints/coco-001.pt
# >>> Epoch: 2
# coco train: 100%|████████████████| 2634/2634 [24:59<00:00,  1.76it/s, loss=1.79]
# coco valid: 100%|██████████████████| 329/329 [00:57<00:00,  5.70it/s, loss=1.66]
# >>> Epoch: 3
# coco train:  20%|███▍             | 527/2634 [05:00<19:58,  1.76it/s, loss=1.66]

# %%
# !python train.py --model_name coco \
                 --train_data_fpath $coco_train_fpath \
                 --valid_data_fpath $coco_valid_fpath \
                 --epochs 10 \
                 --batch_size 40

# %% [markdown]
# ## 2-4. 推論
# テスト画像を使用して，学習済みモデルをテストする

# %%
# テスト画像リスト
TEST_IMAGE_FNAME_LIST = json.load(open(os.path.splitext(coco_test_fpath)[0]+"_list.json"))

# モデル読込
coco_model = build_model(model_fpath='checkpoints/coco-002.pt')
coco_predictor = Predictor(model=coco_model)
# Out:
# Train both prefix and GPT
# Resume pretrained weights from checkpoints/coco-002.pt

# %%
# キャプション生成
image_fname = TEST_IMAGE_FNAME_LIST[100]
image_fpath = os.path.join(image_dpath, image_fname)
pil_image, captions = coco_predictor.caption(image_fpath=image_fpath, beam_size=5)

# %% [markdown]
# # 3. sfcocoデータで追加学習
# cocoデータで学習したモデルを，sfcocoデータによって追加学習する．

# %% [markdown]
# ## 3-1. sfcocoデータを用意

# %%
# キャプション一覧データのパス
captions_fpath = "data/sfcoco/captions.json"

# 画像データのパス
image_dpath = "data/sfcoco/images"

# %% [markdown]
# ## 3-2. 学習用データを生成

# %%
sfcoco_test_fpath, sfcoco_valid_fpath, sfcoco_train_fpath = prepare_data(captions_fpath=captions_fpath,
                                                                         image_dpath=image_dpath,
                                                                         test_ratio=0.1,
                                                                         valid_ratio=0.1,
                                                                         train_ratio=0.8,
                                                                         shuffle=True)

# %%
image_dpath = "data/sfcoco/images"
sfcoco_train_fpath = "data/sfcoco/processed/train.pkl"
sfcoco_valid_fpath = "data/sfcoco/processed/valid.pkl"
sfcoco_test_fpath = "data/sfcoco/processed/test.pkl"

# %% [markdown]
# ## 3-3. 学習

# %%
# !python train.py --model_name cocosfcoco \
                 --pretrained_fpath checkpoints/coco-001.pt \
                 --train_data_fpath $sfcoco_train_fpath \
                 --valid_data_fpath $sfcoco_valid_fpath \
                 --epochs 20 \
                 --batch_size 4
# Out:
# Data size is 648
# Data size is 81
# Train both prefix and GPT
# Resume pretrained weights from checkpoints/coco-001.pt
# >>> Epoch: 0
# cocosfcoco train: 100%|████████████| 162/162 [00:20<00:00,  8.07it/s, loss=4.64]
# cocosfcoco train avg loss: 4.818143297124792
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 47.98it/s, loss=4.57]
# cocosfcoco valid avg loss: 4.4547006487846375
# >>> Epoch: 1
# cocosfcoco train: 100%|████████████| 162/162 [00:20<00:00,  8.10it/s, loss=4.36]
# cocosfcoco train avg loss: 4.131886750091741
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 49.70it/s, loss=3.53]
# cocosfcoco valid avg loss: 3.818846881389618
# >>> Epoch: 2
# cocosfcoco train: 100%|█████████████| 162/162 [00:19<00:00,  8.10it/s, loss=3.1]
# cocosfcoco train avg loss: 3.689472526679804
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 49.94it/s, loss=3.38]
# cocosfcoco valid avg loss: 3.4852192640304565
# >>> Epoch: 3
# cocosfcoco train: 100%|████████████| 162/162 [00:20<00:00,  8.10it/s, loss=2.92]
# cocosfcoco train avg loss: 3.4138987756069796
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 49.85it/s, loss=3.35]
# cocosfcoco valid avg loss: 3.336756682395935
# >>> Epoch: 4
# cocosfcoco train: 100%|████████████| 162/162 [00:20<00:00,  8.10it/s, loss=2.71]
# cocosfcoco train avg loss: 3.2106063380653476
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 49.83it/s, loss=3.09]
# cocosfcoco valid avg loss: 3.227179253101349
# >>> Epoch: 5
# cocosfcoco train: 100%|████████████| 162/162 [00:19<00:00,  8.11it/s, loss=2.45]
# cocosfcoco train avg loss: 3.0273875910558816
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 49.87it/s, loss=2.93]
# cocosfcoco valid avg loss: 3.1524385094642637
# >>> Epoch: 6
# cocosfcoco train: 100%|████████████| 162/162 [00:19<00:00,  8.11it/s, loss=2.56]
# cocosfcoco train avg loss: 2.8513771766497764
# cocosfcoco valid: 100%|███████████████| 20/20 [00:00<00:00, 50.07it/s, loss=3.4]
# cocosfcoco valid avg loss: 3.140958034992218
# >>> Epoch: 7
# cocosfcoco train: 100%|████████████| 162/162 [00:19<00:00,  8.12it/s, loss=2.05]
# cocosfcoco train avg loss: 2.6833925784370045
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 50.24it/s, loss=2.98]
# cocosfcoco valid avg loss: 3.110110676288605
# >>> Epoch: 8
# cocosfcoco train: 100%|████████████| 162/162 [00:21<00:00,  7.66it/s, loss=2.46]
# cocosfcoco train avg loss: 2.5076771209269393
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 41.37it/s, loss=3.35]
# cocosfcoco valid avg loss: 3.1312633633613585
# >>> Epoch: 9
# cocosfcoco train: 100%|████████████| 162/162 [00:19<00:00,  8.12it/s, loss=2.65]
# cocosfcoco train avg loss: 2.3291802825751127
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 50.27it/s, loss=2.16]
# cocosfcoco valid avg loss: 3.1665727257728578
# >>> Epoch: 10
# cocosfcoco train: 100%|████████████| 162/162 [00:21<00:00,  7.63it/s, loss=1.84]
# cocosfcoco train avg loss: 2.1411322782069075
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 40.82it/s, loss=2.82]
# cocosfcoco valid avg loss: 3.198024034500122
# >>> Epoch: 11
# cocosfcoco train: 100%|████████████| 162/162 [00:21<00:00,  7.62it/s, loss=1.48]
# cocosfcoco train avg loss: 1.9232297510276606
# cocosfcoco valid: 100%|██████████████| 20/20 [00:00<00:00, 40.85it/s, loss=3.03]
# cocosfcoco valid avg loss: 3.3175093054771425
# ^C

# %%
from model import build_model
from test import Predictor

# %%
# テスト画像リスト
TEST_IMAGE_FNAME_LIST = json.load(open(os.path.splitext(sfcoco_test_fpath)[0]+"_list.json"))

# モデル読込
cocosfcoco_model = build_model(model_fpath='checkpoints/cocosfcoco-008.pt')
cocosfcoco_predictor = Predictor(model=cocosfcoco_model)
# Out:
# Train both prefix and GPT
# Resume pretrained weights from checkpoints/cocosfcoco-008.pt

# %%
# キャプション生成
for image_fname in TEST_IMAGE_FNAME_LIST:
    image_fpath = os.path.join(image_dpath, image_fname)
    pil_image, captions = cocosfcoco_predictor.caption(image_fpath=image_fpath, beam_size=5)
    print(captions)
# Out:
# ['鴨池のほとりから見た鴨池のほとりの風景。</s>', '鴨池のほとりから見た鴨池のほとりの景色。</s>', '鴨池のほとりから見た鴨池のほとりの景色</s>', '鴨池のほとりで撮ったsfcの秋の風景写真</s>', '鴨池のほとりから見た鴨池のほとりの風景</s>']
# ['オミクロン館とメディアセンター。メディアセンターはメディアセンター棟の2階にある。</s>', 'オミクロン館とメディアセンター。メディアセンターはメディアセンター棟の3階にある。</s>', 'オミクロン館とメディアセンター。メディアセンターはメディアセンター棟の1階にある。</s>', 'オミクロン館とメディアセンター。メディアセンターはメディアセンター棟の4階にある。</s>', 'オミクロン館とメディアセンター。メディアセンターはメディアセンター棟の一番奥にある。</s>']
# ['メディアセンター前のバス停から撮ったメディアセンター前</s>', 'メディアセンター前のバス停から撮ったsfcの風景</s>', 'メディアセンター前のバス停から撮ったメディアセンター前の風景</s>', 'メディアセンター前のバス停から撮ったsfcのバス停</s>', 'メディアセンター前のバス停から撮ったイオタ館</s>']
# ['メディアセンター前のバス停から撮ったsfcのバス停の写真</s>', 'メディアセンター前のバス停から撮ったsfcのバス停。</s>', 'メディアセンター前のバス停から撮ったsfcの入り口</s>', 'メディアセンター前のバス停から撮ったsfcのバス停</s>', 'メディアセンター前のバス停から撮ったsfcの写真</s>']
# ['サブウェイの前の芝生広場にあるオブジェ。</s>', 'サブウェイの前の芝生広場で撮ったサブウェイの看板</s>', 'サブウェイの前の芝生広場で撮ったサブウェイの写真</s>', 'サブウェイの前の芝生広場にあるオブジェ</s>', 'サブウェイの前の芝生広場で撮った芝生の写真</s>']
# ['秋晴れの空の下、慶應大学本館前を歩く慶應大学本館前。</s>', '秋晴れの空の下、慶應大学本館前を歩く慶應大学本館前</s>', '秋晴れの空の下、慶應大学本館前をバスが通っている。</s>', '秋晴れの空の下、慶應大学本館前で撮った慶應大学本館前</s>', '秋晴れの空の下、慶應大学本館前を歩く慶應大学。</s>']
# ['シータ館の入り口。中はガラス張りになっている。</s>', 'シータ館の入り口。中はガラス張りで開放感がある。</s>', 'シータ館の入り口。中は撮影禁止なので写真は無し。</s>', 'シータ館の入り口。中はガラス張りで綺麗。</s>', 'シータ館の入り口。中はガラス張りで開放感がある</s>']
# ['メディアセンターの教室で、授業が行われている。</s>', 'メディアセンターの教室で、授業が行われている様子。</s>', 'メディアセンターの教室。メディアセンターの授業はここで行われる。</s>', 'メディアセンターの教室。メディアセンターの授業はここで行われている。</s>', 'メディアセンターの教室で、授業が行われている様子</s>']
# ['メディアセンターの自習室。自習している人が多い。</s>', 'メディアセンターの自習室で、自習している人がいる。</s>', 'メディアセンターの自習室で、多くの人が勉強している。</s>', 'メディアセンターの自習室で、自習をしている人がいる。</s>', 'メディアセンターの自習室で、自習している人が多い。</s>']
# ['夜に撮ったsfcの夜景。暗くてよく見えない。</s>', '夜に撮ったsfcの夜景。暗くてよくわからない。</s>', '夜に撮ったアルファ館とオメガ館の写真</s>', '夜に撮ったアルファ館とオメガ館の写真。</s>', '夜に撮ったsfcの夜景。夜景が綺麗なのはsfcだけ</s>']
# ['メディアセンターです。ここはメディアセンターです。</s>', 'メディアセンター。メディアセンターはメディアの授業で使用する。</s>', 'メディアセンター。メディアセンターはメディアの授業でよく使う。</s>', 'メディアセンター。メディアセンターはメディアの授業で使う。</s>', 'メディアセンター。メディアセンターはメディア学部の教室。</s>']
# ['生協前のバスロータリー。バスを待つ学生で賑わっている。</s>', '生協前のバスロータリー。バスを待つ学生で賑わう。</s>', '生協前のバスロータリー。バスを待つ学生で賑わっています。</s>', '生協前のバスロータリー。バスを待つ学生で賑わっている</s>', '生協前のバスロータリー。バスを待つ学生で賑わう</s>']
# ['メディアセンターで授業を受けている様子。</s>', 'メディアセンターで授業を受けている様子です。</s>', 'メディアセンターで授業を受けている様子である。</s>', 'メディアセンターで授業を受けている様子を撮影</s>', 'メディアセンターで授業を受けている様子を映した写真</s>']
# ['生協前のバス停から撮ったsfcのバス停の写真</s>', '生協前のバス停から撮ったsfcのバス列とバス停の写真</s>', '生協前のバス停から撮った、sfcのバス列とバス停の写真</s>', '生協前のバス停から撮った、sfcのバス列と学生たち</s>', '生協前のバス停から撮った、sfcのバス列とsfcの入り口</s>']
# ['快晴の空に凧があがっている様子を写真に撮った様子。</s>', '快晴の空に凧があがっている様子を撮った写真</s>', '快晴の空に凧があがっている様子を写真に撮った。</s>', '快晴の空に凧があがっている様子を撮った写真。</s>', '快晴の空に凧があがっている様子を写真に撮った様子</s>']
# ['メディアセンター前のゴミ捨て場。生ゴミが散乱している。</s>', 'メディアセンター前のゴミ捨て場。ゴミが散乱している。</s>', '生協前のゴミ捨て場。生協のゴミ箱は綺麗に掃除されている。</s>', '生協前のゴミ捨て場。生協のゴミ箱は綺麗な方だと思う。</s>', '生協前のゴミ捨て場。生協のゴミ箱は綺麗に掃除されている</s>']
# ['メディアセンターの机。机の上にはノートパソコンが置いてある。</s>', 'メディアセンター前の椅子。座り心地は悪くない。</s>', 'メディアセンターの椅子。座り心地は悪くないが、座り心地が悪い。</s>', 'メディアセンターの机。机の上にはノートパソコンが置いてある</s>', 'メディアセンターの椅子。座り心地は悪くないが、座り心地がいいとは言えない。</s>']
# ['イオタ館の自習室。授業がない日はここで自習をする。</s>', 'イオタ館の自習室で、自習をしている人がいる。</s>', 'イオタ館の自習室で、自習をしている人達がいます。</s>', 'イオタ館の自習室。自習している人が多い。</s>', 'イオタ館の自習室で、自習をしている人が多い。</s>']
# ['メディアセンターの椅子。座り心地が良さそう。</s>', 'メディアセンターの椅子。座り心地は悪くない。</s>', 'メディアセンターの椅子。座り心地がとても良い。</s>', 'メディアセンターの椅子。座り心地がいい。</s>', 'メディアセンターの椅子。座り心地は悪くないが、座り心地が悪い。</s>']
# ['メディアセンターで授業を受けている様子。</s>', 'sfcのメディアセンターで授業を受けている様子。</s>', 'sfcのメディアセンターで授業を受けている様子</s>', 'sfcのメディアセンターで、授業を受けている様子。</s>', 'sfcのメディアセンターで授業を受けている写真</s>']
# ['メディアセンター前の階段付近から撮ったメディアセンター前の写真</s>', 'メディアセンター前の階段付近から撮ったsfcの階段</s>', 'メディアセンター前の階段付近から見たsfcの階段</s>', 'メディアセンター前の階段付近から撮ったメディアセンター前</s>', 'メディアセンター前の階段付近から撮った階段の写真</s>']
# ['福沢諭吉の像。福沢諭吉の像は福沢諭吉の胸像である。</s>', '福沢諭吉の像。福沢諭吉の像は福沢諭吉先生の銅像です。</s>', '福沢諭吉の像。福沢諭吉の像は福沢諭吉先生の像です。</s>', '福沢諭吉の像。福沢諭吉の像は福沢諭吉先生の像である。</s>', '福沢諭吉の像。福沢諭吉の像は福沢諭吉先生の像より少し大きい。</s>']
# ['鴨池のほとりで昼食をとった後、sfcを後にする。</s>', '鴨池のほとりで昼食をとった後、sfcを後にする</s>', '鴨池のほとりで昼食をとっている人達が写った写真</s>', '鴨池のほとりで昼食をとった後、sfcを後にした。</s>', '鴨池のほとりで昼食をとった後、sfcを後にした</s>']
# ['メディアセンター内にあるメディアセンターです。</s>', 'メディアセンター。メディアセンターはメディアセンター棟の1階にある。</s>', 'メディアセンター内にあるメディアセンター。</s>', 'メディアセンター。メディアセンターはメディアセンター棟の3階にある。</s>', 'メディアセンター内にあるメディアセンターの外観。</s>']
# ['バスが停車しているバス停。雨が降っているので傘をさしている人が多い。</s>', 'バスが停車しているバス停。雨が降っているので傘をさしている人がいる。</s>', 'バスが停車しているバス停。雨が降っているので濡れている。</s>', 'バスが停車しているバス停。雨が降っているので傘をさしている。</s>', 'バスが停車しているバス停。雨が降っているので傘を差す。</s>']
# ['鴨池のほとりで撮ったsfcのキャンパスの写真</s>', '鴨池のほとりで撮ったsfcの秋の風景写真</s>', '鴨池のほとりで撮ったsfcの秋の風景。紅葉もきれい。</s>', '鴨池のほとりで撮ったsfcの秋の風景。紅葉がきれい。</s>', '鴨池のほとりで撮ったsfcの秋の風景の写真</s>']
# ['生協前にあるsfcの道路標識です。sfcのマークが入っています。</s>', '生協前にあるsfcの道路標識です。sfcのマークがあります。</s>', '生協前にあるsfcの道路標識です。sfcのマークが入ってます。</s>', '生協前にあるsfcの道路標識です。sfcのマークもあります。</s>', '生協前にあるsfcの道路標識です。sfcのマークが入っています</s>']
# ['メディアセンター前で撮ったsfcの正面入り口の写真</s>', 'メディアセンター前で撮ったsfcの入り口の写真</s>', 'メディアセンター前で撮ったメディアセンター前の写真</s>', 'メディアセンター前で撮ったメディアセンターの写真</s>', 'メディアセンター前の階段を降りたところ。</s>']
# ['紅葉した木々が生い茂る生協前の道。木漏れ日が綺麗。</s>', '紅葉した木々が生い茂る生協前の道。木漏れ日が気持ちいい。</s>', '紅葉した木々が生い茂る生協前の道。木漏れ日が美しい。</s>', '紅葉した木々が生い茂るsfcのバス停の写真</s>', '紅葉した木々が生い茂る生協前の道。木漏れ日が綺麗</s>']
# ['鴨池のほとりで、鴨を眺めながら昼食をとる。</s>', '鴨池のほとりで昼食をとった後、鴨池を眺める。</s>', '鴨池のほとりで昼食をとった後、鴨池を眺める</s>', '鴨池のほとりで、鴨を眺めながら昼食を取る。</s>', '鴨池のほとりで、鴨を眺めながら昼食をとる</s>']
# ['メディアセンター前にあるメディアセンターの入り口。</s>', 'メディアセンター前にあるメディアセンターの入り口</s>', 'メディアセンター前にあるメディアセンターの看板。</s>', 'メディアセンター前にあるメディアセンターの看板</s>', 'メディアセンター前にあるメディアセンターの入口</s>']
# ['サブウェイのテラスから撮ったsfcの坂道の写真</s>', 'サブウェイのテラスから見たsfcの坂道の風景</s>', 'サブウェイのテラスから撮ったsfcの坂道の風景</s>', 'メディアセンター前の階段から見たsfcの坂道</s>', 'サブウェイのテラスから撮ったsfcの風景。</s>']
# ['メディアセンター。メディアセンターはメディア系の授業でよく使用される。</s>', 'メディアセンター。メディアセンターはメディア系の授業でよく利用される。</s>', 'メディアセンター。メディアセンターはメディアの授業で使用する。</s>', 'メディアセンター。メディアセンターはメディア学部の教室。</s>', 'メディアセンター。メディアセンターはメディアの授業で使う。</s>']
# ['雨が降る中、鴨池のほとりに人が集まっている。</s>', '雨が降る中、鴨池のほとりにたたずむ人がいます。</s>', '雨が降る中、鴨池のほとりにたたずむ人影。</s>', '雨が降る中、鴨池のほとりに人が集まっています。</s>', '雨が降る中、鴨池のほとりに人が集まっている</s>']
# ['オミクロン館。メディアセンターになっている。</s>', 'オミクロン館。メディアセンターとして使われている。</s>', 'メディアセンター前のメディアセンター前の写真。</s>', 'オミクロン館。メディアセンターの隣にある。</s>', 'メディアセンター前のメディアセンター前の写真</s>']
# ['メディアセンター前のメディアセンター前の写真。</s>', 'メディアセンター。メディアセンターはメディア系の授業でよく使われます。</s>', 'メディアセンターです。メディアセンターはメディア学部の授業で使われます。</s>', 'メディアセンター前のメディアセンター前の写真</s>', 'メディアセンター。メディアセンターはメディア学部の教室。</s>']
# ['福沢諭吉像と福沢諭吉先生の銅像が並んで立っています。</s>', '福沢諭吉像と福沢諭吉先生の銅像が並んでいる様子。</s>', '福沢諭吉像と福沢諭吉先生の銅像が並んで立っている。</s>', '福沢諭吉像と福沢諭吉先生の像が並んでいる様子。</s>', '福沢諭吉像と福沢諭吉先生の像が並んで立っている。</s>']
# ['メディアセンター前のメディアセンター前の写真。</s>', 'メディアセンター前のメディアセンター前の写真</s>', 'メディアセンター。メディアセンターはメディアセンター祭で有名。</s>', 'メディアセンター。メディアセンターはメディアの授業で使う。</s>', 'メディアセンター。メディアセンターはメディアセンター祭で有名</s>']
# ['イオタ館。イオタ館はメディアセンターになっている。</s>', 'イオタ館。イオタ館はメディアセンターとして利用されています。</s>', 'イオタ館。イオタ館はメディアセンターとして使われている。</s>', 'イオタ館。イオタ館はメディアセンターとして利用されます。</s>', 'イオタ館。イオタ館はメディアセンターとして利用している。</s>']
# ['紅葉した木々が生い茂るバス停。バスも停まる。</s>', '紅葉した木々が生い茂るバス停。バスも停まっている。</s>', '紅葉した木々が生い茂るバスロータリーから見た紅葉</s>', '紅葉した木々が生い茂るバス停から見た秋の風景</s>', '紅葉した木々が生い茂るバス停から見た紅葉</s>']
# ['メディアセンター裏の階段から見たメディアセンター。</s>', 'メディアセンター裏の階段から見たメディアセンター</s>', 'メディアセンター裏の階段から見たオメガ館。</s>', 'メディアセンター裏の階段から見たオメガ館</s>', 'メディアセンター裏の階段。メディアセンターの入り口。</s>']
# ['イオタ館とメディアセンター。メディアセンターはメディアセンター棟の2階にある。</s>', 'イオタ館とメディアセンター。メディアセンターはメディアセンター棟の3階にある。</s>', 'イオタ館とメディアセンター。メディアセンターはメディアセンター棟の1階にある。</s>', 'イオタ館。イオタ館はメディアセンターになっている。</s>', 'イオタ館とメディアセンター。メディアセンターはメディアセンター棟の2階。</s>']
# ['デルタ館のトイレ。綺麗に掃除が行き届いている。</s>', 'デルタ館のトイレ。綺麗に掃除されている。</s>', 'デルタ館のトイレ。綺麗に掃除が行き届いており、綺麗な状態を保っている。</s>', 'デルタ館のトイレ。綺麗に掃除されているのが分かる。</s>', 'デルタ館のトイレ。綺麗に掃除が行き届いている</s>']
